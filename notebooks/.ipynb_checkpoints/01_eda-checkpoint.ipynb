# %%
import pandas as pd
import numpy as np


insu_df = pd.read_csv("../dataset/raw_dataset/Dataset.csv")

# %%
# checking how many att val's have been missing

for att in insu_df:

    print(f"{att}:{insu_df[att].isnull().sum()}",end = "\n")
# Out:
# ID:0
# ID_policy:0
# ID_insured:0
# period:0
# date_effect_insured:0
# date_lapse_insured:167181
# date_effect_policy:0
# date_lapse_policy:174568
# year_effect_insured:0
# year_lapse_insured:167181
# year_effect_policy:0
# year_lapse_policy:174568
# exposure_time:0
# lapse:0
# seniority_insured:0
# seniority_policy:0
# type_policy:0
# type_policy_dg:0
# type_product:0
# reimbursement:0
# new_business:0
# distribution_channel:0
# gender:0
# age:0
# premium:0
# cost_claims_year:0
# n_medical_services:0
# n_insured_pc:0
# n_insured_mun:0
# n_insured_prov:0
# IICIMUN:10886
# IICIPROV:5701
# C_H:10886
# C_GI:13213
# C_II:13213
# C_IE_P:13213
# C_IE_S:13213
# C_IE_T:13213
# C_GE_P:13213
# C_GE_S:13213
# C_GE_T:13213
# C_C:10556

# %%
insu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228711 entries, 0 to 228710
# Data columns (total 42 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    228711 non-null  object
#  1   ID_policy             228711 non-null  int64
#  2   ID_insured            228711 non-null  int64
#  3   period                228711 non-null  int64
#  4   date_effect_insured   228711 non-null  object
#  5   date_lapse_insured    61530 non-null   object
#  6   date_effect_policy    228711 non-null  object
#  7   date_lapse_policy     54143 non-null   object
#  8   year_effect_insured   228711 non-null  int64
#  9   year_lapse_insured    61530 non-null   float64
#  10  year_effect_policy    228711 non-null  int64
#  11  year_lapse_policy     54143 non-null   float64
#  12  exposure_time         228711 non-null  float64
#  13  lapse                 228711 non-null  int64
#  14  seniority_insured     228711 non-null  int64
#  15  seniority_policy      228711 non-null  int64
#  16  type_policy           228711 non-null  object
#  17  type_policy_dg        228711 non-null  object
#  18  type_product          228711 non-null  object
#  19  reimbursement         228711 non-null  object
#  20  new_business          228711 non-null  object
#  21  distribution_channel  228711 non-null  object
#  22  gender                228711 non-null  object
#  23  age                   228711 non-null  int64
#  24  premium               228711 non-null  float64
#  25  cost_claims_year      228711 non-null  float64
#  26  n_medical_services    228711 non-null  int64
#  27  n_insured_pc          228711 non-null  int64
#  28  n_insured_mun         228711 non-null  int64
#  29  n_insured_prov        228711 non-null  int64
#  30  IICIMUN               217825 non-null  float64
#  31  IICIPROV              223010 non-null  float64
#  32  C_H                   217825 non-null  object
#  33  C_GI                  215498 non-null  float64
#  34  C_II                  215498 non-null  float64
#  35  C_IE_P                215498 non-null  float64
#  36  C_IE_S                215498 non-null  float64
#  37  C_IE_T                215498 non-null  float64
#  38  C_GE_P                215498 non-null  float64
#  39  C_GE_S                215498 non-null  float64
#  40  C_GE_T                215498 non-null  float64
#  41  C_C                   218155 non-null  object
# dtypes: float64(15), int64(13), object(14)
# memory usage: 73.3+ MB
