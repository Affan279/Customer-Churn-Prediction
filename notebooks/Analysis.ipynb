# %% [markdown]
# How is portfolio size trending across the 3 periods — growing, shrinking, or flat? (compare new_business
# counts vs. lapse counts per period)

# %%
import os
import pandas as pd

os.chdir(r"C:\Users\affan\OneDrive\Desktop\Projects\Insurance_prediction")

insu_df = pd.read_csv("dataset/raw_dataset/Dataset.csv")
